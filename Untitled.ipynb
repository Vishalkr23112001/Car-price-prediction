# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
cols = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
data = pd.read_csv(r"C:\Users\abc\OneDrive\Documents\car_price.csv",names = cols)
data.shape
# Out:
# (206, 26)

# %%
data.head()
# Out:
#   symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0   Column1           Column2      Column3   Column4    Column5      Column6
# 1         3                 ?  alfa-romero       gas        std          two
# 2         3                 ?  alfa-romero       gas        std          two
# 3         1                 ?  alfa-romero       gas        std          two
# 4         2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location wheel-base  ... engine-size  \
# 0      Column7      Column8         Column9   Column10  ...    Column17
# 1  convertible          rwd           front       88.6  ...         130
# 2  convertible          rwd           front       88.6  ...         130
# 3    hatchback          rwd           front       94.5  ...         152
# 4        sedan          fwd           front       99.8  ...         109
#
#   fuel-system      bore    stroke compression-ratio horsepower  peak-rpm  \
# 0    Column18  Column19  Column20          Column21   Column22  Column23
# 1        mpfi      3.47      2.68                 9        111      5000
# 2        mpfi      3.47      2.68                 9        111      5000
# 3        mpfi      2.68      3.47                 9        154      5000
# 4        mpfi      3.19      3.40                10        102      5500
#
#    city-mpg highway-mpg     price
# 0  Column24    Column25  Column26
# 1        21          27     13495
# 2        21          27     16500
# 3        19          26     16500
# 4        24          30     13950
#
# [5 rows x 26 columns]

# %%
# Data Wrangling

# %%
data = data.replace('?',np.nan)
data.head(10)
# Out:
#   symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0   Column1           Column2      Column3   Column4    Column5      Column6
# 1         3               NaN  alfa-romero       gas        std          two
# 2         3               NaN  alfa-romero       gas        std          two
# 3         1               NaN  alfa-romero       gas        std          two
# 4         2               164         audi       gas        std         four
# 5         2               164         audi       gas        std         four
# 6         2               NaN         audi       gas        std          two
# 7         1               158         audi       gas        std         four
# 8         1               NaN         audi       gas        std         four
# 9         1               158         audi       gas      turbo         four
#
#     body-style drive-wheels engine-location wheel-base  ... engine-size  \
# 0      Column7      Column8         Column9   Column10  ...    Column17
# 1  convertible          rwd           front       88.6  ...         130
# 2  convertible          rwd           front       88.6  ...         130
# 3    hatchback          rwd           front       94.5  ...         152
# 4        sedan          fwd           front       99.8  ...         109
# 5        sedan          4wd           front       99.4  ...         136
# 6        sedan          fwd           front       99.8  ...         136
# 7        sedan          fwd           front      105.8  ...         136
# 8        wagon          fwd           front      105.8  ...         136
# 9        sedan          fwd           front      105.8  ...         131
#
#   fuel-system      bore    stroke compression-ratio horsepower  peak-rpm  \
# 0    Column18  Column19  Column20          Column21   Column22  Column23
# 1        mpfi      3.47      2.68                 9        111      5000
# 2        mpfi      3.47      2.68                 9        111      5000
# 3        mpfi      2.68      3.47                 9        154      5000
# 4        mpfi      3.19      3.40                10        102      5500
# 5        mpfi      3.19      3.40                 8        115      5500
# 6        mpfi      3.19      3.40               8.5        110      5500
# 7        mpfi      3.19      3.40               8.5        110      5500
# 8        mpfi      3.19      3.40               8.5        110      5500
# 9        mpfi      3.13      3.40               8.3        140      5500
#
#    city-mpg highway-mpg     price
# 0  Column24    Column25  Column26
# 1        21          27     13495
# 2        21          27     16500
# 3        19          26     16500
# 4        24          30     13950
# 5        18          22     17450
# 6        19          25     15250
# 7        19          25     17710
# 8        19          25     18920
# 9        17          20     23875
#
# [10 rows x 26 columns]

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
data = data.drop(data.index[0])
data.head()
# Out:
#   symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1         3               NaN  alfa-romero       gas        std          two
# 2         3               NaN  alfa-romero       gas        std          two
# 3         1               NaN  alfa-romero       gas        std          two
# 4         2               164         audi       gas        std         four
# 5         2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location wheel-base  ... engine-size  \
# 1  convertible          rwd           front       88.6  ...         130
# 2  convertible          rwd           front       88.6  ...         130
# 3    hatchback          rwd           front       94.5  ...         152
# 4        sedan          fwd           front       99.8  ...         109
# 5        sedan          4wd           front       99.4  ...         136
#
#   fuel-system  bore stroke compression-ratio horsepower peak-rpm city-mpg  \
# 1        mpfi  3.47   2.68                 9        111     5000       21
# 2        mpfi  3.47   2.68                 9        111     5000       21
# 3        mpfi  2.68   3.47                 9        154     5000       19
# 4        mpfi  3.19   3.40                10        102     5500       24
# 5        mpfi  3.19   3.40                 8        115     5500       18
#
#   highway-mpg  price
# 1          27  13495
# 2          27  16500
# 3          26  16500
# 4          30  13950
# 5          22  17450
#
# [5 rows x 26 columns]

# %%
#Normalised-losses
avg_norm_loss = data['normalized-losses'].astype('float').mean()
print("The average is {}".format(avg_norm_loss))
data["normalized-losses"].replace(np.NaN, avg_norm_loss, inplace = True)
# Out:
# The average is 122.0

# %%
data.head()
# Out:
#   symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1         3             122.0  alfa-romero       gas        std          two
# 2         3             122.0  alfa-romero       gas        std          two
# 3         1             122.0  alfa-romero       gas        std          two
# 4         2               164         audi       gas        std         four
# 5         2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location wheel-base  ... engine-size  \
# 1  convertible          rwd           front       88.6  ...         130
# 2  convertible          rwd           front       88.6  ...         130
# 3    hatchback          rwd           front       94.5  ...         152
# 4        sedan          fwd           front       99.8  ...         109
# 5        sedan          4wd           front       99.4  ...         136
#
#   fuel-system  bore stroke compression-ratio horsepower peak-rpm city-mpg  \
# 1        mpfi  3.47   2.68                 9        111     5000       21
# 2        mpfi  3.47   2.68                 9        111     5000       21
# 3        mpfi  2.68   3.47                 9        154     5000       19
# 4        mpfi  3.19   3.40                10        102     5500       24
# 5        mpfi  3.19   3.40                 8        115     5500       18
#
#   highway-mpg  price
# 1          27  13495
# 2          27  16500
# 3          26  16500
# 4          30  13950
# 5          22  17450
#
# [5 rows x 26 columns]

# %%
#Bore values
avg_bore = data['bore'].astype('float').mean()
data['bore'].replace(np.nan,avg_bore,inplace = True)

#Stroke Values
avg_stroke = data['stroke'].astype('float').mean(axis = 0)
data['stroke'].replace(np.nan, avg_stroke, inplace = True)

#horsepower Values 
avg_horsepower = data['horsepower'].astype('float').mean(axis=0)
data['horsepower'].replace(np.nan, avg_horsepower, inplace=True)

#Peak RPM 
avg_peakrpm= data['peak-rpm'].astype('float').mean(axis=0)
data['peak-rpm'].replace(np.nan, avg_peakrpm, inplace=True)

# %%
print(data['num-of-doors'].value_counts())
print(data['num-of-doors'].value_counts().idxmax())
data["num-of-doors"].replace(np.nan, "four", inplace=True)
data.head()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64
# four
#   symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1         3             122.0  alfa-romero       gas        std          two
# 2         3             122.0  alfa-romero       gas        std          two
# 3         1             122.0  alfa-romero       gas        std          two
# 4         2               164         audi       gas        std         four
# 5         2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location wheel-base  ... engine-size  \
# 1  convertible          rwd           front       88.6  ...         130
# 2  convertible          rwd           front       88.6  ...         130
# 3    hatchback          rwd           front       94.5  ...         152
# 4        sedan          fwd           front       99.8  ...         109
# 5        sedan          4wd           front       99.4  ...         136
#
#   fuel-system  bore stroke compression-ratio horsepower peak-rpm city-mpg  \
# 1        mpfi  3.47   2.68                 9        111     5000       21
# 2        mpfi  3.47   2.68                 9        111     5000       21
# 3        mpfi  2.68   3.47                 9        154     5000       19
# 4        mpfi  3.19   3.40                10        102     5500       24
# 5        mpfi  3.19   3.40                 8        115     5500       18
#
#   highway-mpg  price
# 1          27  13495
# 2          27  16500
# 3          26  16500
# 4          30  13950
# 5          22  17450
#
# [5 rows x 26 columns]

# %%
#Dropping the values with no price
data.dropna(subset = ['price'], axis = 0, inplace = True)
data.shape
# Out:
# (201, 26)

# %%
data.dtypes
# Out:
# symboling            object
# normalized-losses    object
# make                 object
# fuel-type            object
# aspiration           object
# num-of-doors         object
# body-style           object
# drive-wheels         object
# engine-location      object
# wheel-base           object
# length               object
# width                object
# height               object
# curb-weight          object
# engine-type          object
# num-of-cylinders     object
# engine-size          object
# fuel-system          object
# bore                 object
# stroke               object
# compression-ratio    object
# horsepower           object
# peak-rpm             object
# city-mpg             object
# highway-mpg          object
# price                object
# dtype: object

# %%
data[["bore", "stroke"]] = data[["bore", "stroke"]].astype("float")
data[["symboling","normalized-losses","curb-weight"]] = data[["symboling","normalized-losses","curb-weight"]].astype("int")
data[["price"]] = data[["price"]].astype("float")
data[["peak-rpm"]] = data[["peak-rpm"]].astype("float")
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 1          3                122  alfa-romero       gas        std
# 2          3                122  alfa-romero       gas        std
# 3          1                122  alfa-romero       gas        std
# 4          2                164         audi       gas        std
# 5          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location wheel-base  ...  \
# 1          two  convertible          rwd           front       88.6  ...
# 2          two  convertible          rwd           front       88.6  ...
# 3          two    hatchback          rwd           front       94.5  ...
# 4         four        sedan          fwd           front       99.8  ...
# 5         four        sedan          4wd           front       99.4  ...
#
#   engine-size fuel-system  bore  stroke compression-ratio horsepower peak-rpm  \
# 1         130        mpfi  3.47    2.68                 9        111   5000.0
# 2         130        mpfi  3.47    2.68                 9        111   5000.0
# 3         152        mpfi  2.68    3.47                 9        154   5000.0
# 4         109        mpfi  3.19    3.40                10        102   5500.0
# 5         136        mpfi  3.19    3.40                 8        115   5500.0
#
#   city-mpg  highway-mpg    price
# 1       21           27  13495.0
# 2       21           27  16500.0
# 3       19           26  16500.0
# 4       24           30  13950.0
# 5       18           22  17450.0
#
# [5 rows x 26 columns]

# %%
data.dtypes
# Out:
# symboling              int32
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base            object
# length                object
# width                 object
# height                object
# curb-weight            int32
# engine-type           object
# num-of-cylinders      object
# engine-size           object
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio     object
# horsepower            object
# peak-rpm             float64
# city-mpg              object
# highway-mpg           object
# price                float64
# dtype: object

# %%
data[['city-mpg','highway-mpg','engine-size']] = data[['city-mpg','highway-mpg','engine-size']].astype("int")
data[['wheel-base','length','width','height','compression-ratio']] = data[['wheel-base','length','width','height','compression-ratio']].astype("float")
data.dtypes
# Out:
# symboling              int32
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int32
# engine-type           object
# num-of-cylinders      object
# engine-size            int32
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int32
# highway-mpg            int32
# price                float64
# dtype: object

# %%
#Analysing individual feature patterns using Visualisation

# %%
data.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008153           0.055045    0.158018  0.123952
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# peak-rpm            0.279740           0.239543   -0.360305 -0.285970
# city-mpg           -0.035527          -0.225016   -0.470606 -0.665192
# highway-mpg         0.036233          -0.181877   -0.543304 -0.698142
# price              -0.082391           0.133999    0.584642  0.690628
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling         -0.242423 -0.550160    -0.233118    -0.110581 -0.140019
# normalized-losses  0.086802 -0.373737     0.099404     0.112360 -0.029862
# wheel-base         0.814507  0.590742     0.782097     0.572027  0.493244
# length             0.857170  0.492063     0.880665     0.685025  0.608971
# width              1.000000  0.306002     0.866201     0.729436  0.544885
# height             0.306002  1.000000     0.307581     0.074694  0.180449
# curb-weight        0.866201  0.307581     1.000000     0.849072  0.644060
# engine-size        0.729436  0.074694     0.849072     1.000000  0.572609
# bore               0.544885  0.180449     0.644060     0.572609  1.000000
# stroke             0.188822 -0.060663     0.167438     0.205928 -0.055390
# compression-ratio  0.189867  0.259737     0.156433     0.028889  0.001263
# peak-rpm          -0.245800 -0.309974    -0.279361    -0.256733 -0.267392
# city-mpg          -0.633531 -0.049800    -0.749543    -0.650546 -0.582027
# highway-mpg       -0.680635 -0.104812    -0.794889    -0.679571 -0.591309
# price              0.751265  0.135486     0.834415     0.872335  0.543155
#
#                      stroke  compression-ratio  peak-rpm  city-mpg  \
# symboling         -0.008153          -0.182196  0.279740 -0.035527
# normalized-losses  0.055045          -0.114713  0.239543 -0.225016
# wheel-base         0.158018           0.250313 -0.360305 -0.470606
# length             0.123952           0.159733 -0.285970 -0.665192
# width              0.188822           0.189867 -0.245800 -0.633531
# height            -0.060663           0.259737 -0.309974 -0.049800
# curb-weight        0.167438           0.156433 -0.279361 -0.749543
# engine-size        0.205928           0.028889 -0.256733 -0.650546
# bore              -0.055390           0.001263 -0.267392 -0.582027
# stroke             1.000000           0.187871 -0.063561 -0.033956
# compression-ratio  0.187871           1.000000 -0.435780  0.331425
# peak-rpm          -0.063561          -0.435780  1.000000 -0.115413
# city-mpg          -0.033956           0.331425 -0.115413  1.000000
# highway-mpg       -0.034636           0.268465 -0.058598  0.972044
# price              0.082269           0.071107 -0.101616 -0.686571
#
#                    highway-mpg     price
# symboling             0.036233 -0.082391
# normalized-losses    -0.181877  0.133999
# wheel-base           -0.543304  0.584642
# length               -0.698142  0.690628
# width                -0.680635  0.751265
# height               -0.104812  0.135486
# curb-weight          -0.794889  0.834415
# engine-size          -0.679571  0.872335
# bore                 -0.591309  0.543155
# stroke               -0.034636  0.082269
# compression-ratio     0.268465  0.071107
# peak-rpm             -0.058598 -0.101616
# city-mpg              0.972044 -0.686571
# highway-mpg           1.000000 -0.704692
# price                -0.704692  1.000000

# %%
#Finding correlation coefficients

# %%
data[['bore','stroke' ,'compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio
# bore               1.000000 -0.055390           0.001263
# stroke            -0.055390  1.000000           0.187871
# compression-ratio  0.001263  0.187871           1.000000

# %%
sns.regplot(x = 'engine-size', y = 'price', data = data)
plt.ylim(0, )
# Out:
# (0.0, 53762.72737915656)

# %%
#As the engine-size goes up, the price goes up: this indicates a positive direct correlation between these two variables. Engine size seems like a pretty good predictor of price since the regression line is almost a perfect diagonal line.

# %%
data['engine-size'].corr(data['price'])
# Out:
# 0.8723351674455189

# %%
#We can examine the correlation between 'engine-size' and 'price' and see it's approximately 0.87

# %%
sns.regplot(x = 'highway-mpg', y = 'price', data = data)
plt.title("Highway Miles per Gallon vs Price")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
data['highway-mpg'].corr(data['price'])
# Out:
# -0.7046922650589534

# %%
sns.regplot(x = 'peak-rpm', y = 'price', data = data)
# Out:
# <AxesSubplot:xlabel='peak-rpm', ylabel='price'>

# %%
data['peak-rpm'].corr(data['price'])
# Out:
# -0.1016158740758814

# %%
#Categorial variables

# %%
sns.boxplot(x = 'body-style', y = 'price', data = data)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015  174.200995   65.889055
# std      1.254802           31.99625    6.066366   12.322175    2.101471
# min     -2.000000           65.00000   86.600000  141.100000   60.300000
# 25%      0.000000          101.00000   94.500000  166.800000   64.100000
# 50%      1.000000          122.00000   97.000000  173.200000   65.500000
# 75%      2.000000          137.00000  102.400000  183.500000   66.600000
# max      3.000000          256.00000  120.900000  208.100000   72.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256874
# std      2.447822   517.296727    41.546834    0.268072    0.316048
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2169.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2926.000000   141.000000    3.580000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio     peak-rpm    city-mpg  highway-mpg         price
# count         201.000000   201.000000  201.000000   201.000000    201.000000
# mean           10.164279  5117.665368   25.179104    30.686567  13207.129353
# std             4.004965   478.113805    6.423220     6.815150   7947.066342
# min             7.000000  4150.000000   13.000000    16.000000   5118.000000
# 25%             8.600000  4800.000000   19.000000    25.000000   7775.000000
# 50%             9.000000  5125.369458   24.000000    30.000000  10295.000000
# 75%             9.400000  5500.000000   30.000000    34.000000  16500.000000
# max            23.000000  6600.000000   49.000000    54.000000  45400.000000

# %%
data.describe(include = 'object')
# Out:
#           make fuel-type aspiration num-of-doors body-style drive-wheels  \
# count      201       201        201          201        201          201
# unique      22         2          2            2          5            3
# top     toyota       gas        std         four      sedan          fwd
# freq        32       181        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system horsepower
# count              201         201              201         201        201
# unique               2           6                7           8         59
# top              front         ohc             four        mpfi         68
# freq               198         145              157          92         19

# %%
#value_counts

# %%
data['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
drive_counts = data['drive-wheels'].value_counts()
drive_counts
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
drive_counts.index.name = 'drive-wheels'
drive_counts
# Out:
# drive-wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
data['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
group_one = data[['drive-wheels','body-style','price']]

# %%
# grouping results 
group_one = group_one.groupby(['drive-wheels'], as_index = False).mean()
group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
# grouping results
gptest = data[['drive-wheels','body-style','price']]
grouped_test1 = gptest.groupby(['drive-wheels','body-style'], as_index = False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot.dtypes
# Out:
#        body-style
# price  convertible    float64
#        hardtop        float64
#        hatchback      float64
#        sedan          float64
#        wagon          float64
# dtype: object

# %%
plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

# label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

# move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor = False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor = False)

# insert labels
ax.set_xticklabels(row_labels, minor = False)
ax.set_yticklabels(col_labels, minor = False)

plt.xticks(rotation = 90)

fig.colorbar(im)
plt.show()

# %%
#Wheel base vs Price
pearson_coef, p_value = stats.pearsonr(data['wheel-base'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.584641822265508  with a P-value of P = 8.076488270733218e-20

# %%
#Conclusion:
#Since the p-value is  <  0.001, the correlation between wheel-base and price is statistically significant, although the linear relationship isn't extremely strong (~0.585)

# %%
#Horsepower vs Price
pearson_coef, p_value = stats.pearsonr(data['horsepower'].astype("float"), data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8095745670036559  with a P-value of P =  6.369057428260101e-48

# %%
#Length Vs Price
pearson_coef, p_value = stats.pearsonr(data['length'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6906283804483642  with a P-value of P =  8.016477466158759e-30

# %%
plt.pcolor(data.corr(), cmap = 'RdBu')
plt.colorbar()
plt.show()

# %%
sns.heatmap(data.corr(), annot = True)
sns.set(rc={'figure.figsize':(10,10)})

# %%
grouped_test2 = gptest[['drive-wheels', 'price']].groupby(['drive-wheels'])
grouped_test2.head(10)
# Out:
#     drive-wheels    price
# 1            rwd  13495.0
# 2            rwd  16500.0
# 3            rwd  16500.0
# 4            fwd  13950.0
# 5            4wd  17450.0
# 6            fwd  15250.0
# 7            fwd  17710.0
# 8            fwd  18920.0
# 9            fwd  23875.0
# 11           rwd  16430.0
# 12           rwd  16925.0
# 13           rwd  20970.0
# 14           rwd  21105.0
# 15           rwd  24565.0
# 16           rwd  30760.0
# 17           rwd  41315.0
# 19           fwd   5151.0
# 20           fwd   6295.0
# 21           fwd   6575.0
# 22           fwd   5572.0
# 23           fwd   6377.0
# 141          4wd   7603.0
# 145          4wd   9233.0
# 146          4wd  11259.0
# 149          4wd   8013.0
# 150          4wd  11694.0
# 155          4wd   7898.0
# 156          4wd   8778.0

# %%
gptest.head()
# Out:
#   drive-wheels   body-style    price
# 1          rwd  convertible  13495.0
# 2          rwd  convertible  16500.0
# 3          rwd    hatchback  16500.0
# 4          fwd        sedan  13950.0
# 5          4wd        sedan  17450.0

# %%
grouped_test2.get_group('4wd')['price']
# Out:
# 5      17450.0
# 141     7603.0
# 145     9233.0
# 146    11259.0
# 149     8013.0
# 150    11694.0
# 155     7898.0
# 156     8778.0
# Name: price, dtype: float64

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23
